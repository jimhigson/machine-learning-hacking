# %%
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense, Activation

import numpy as np
# Out:
# Using TensorFlow backend.

# %%
X = np.array([[0,3], [2,2], [1,5], [2,4], [-1,10], [100, 100]])

# %%
model=Sequential()
model.add(Dense(units=2, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=1))

#sgd = optimizers.SGD(lr=0.02, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
Y=np.array([3,4,6,6,9, 200])

# %%
model.fit(X, Y, epochs=1000)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 1s 84ms/step - loss: 6696.8008
# Epoch 2/1000
# 6/6 [==============================] - 0s 282us/step - loss: 6618.1040
# Epoch 3/1000
# 6/6 [==============================] - 0s 349us/step - loss: 6258.9487
# Epoch 4/1000
# 6/6 [==============================] - 0s 366us/step - loss: 6158722560.0000
# Epoch 5/1000
# 6/6 [==============================] - 0s 313us/step - loss: 38349376.0000
# Epoch 6/1000
# 6/6 [==============================] - 0s 340us/step - loss: 417461.0000
# Epoch 7/1000
# 6/6 [==============================] - 0s 299us/step - loss: 401137.5000
# Epoch 8/1000
# 6/6 [==============================] - 0s 299us/step - loss: 385460.5000
# Epoch 9/1000
# 6/6 [==============================] - 0s 287us/step - loss: 370404.2500
# Epoch 10/1000
# 6/6 [==============================] - 0s 290us/step - loss: 355944.2188
# Epoch 11/1000
# 6/6 [==============================] - 0s 332us/step - loss: 342056.7812
# ...

# %%
model.predict(np.array([[1,5]]))
# Out:
# array([[37.99991]], dtype=float32)

# %%
model.predict(np.array([[2,5]]))
# Out:
# array([[37.99991]], dtype=float32)

# %%
model.predict(np.array([[1,2]]))
# Out:
# array([[37.99991]], dtype=float32)

# %%
model.predict(np.array([[2,2]]))
# Out:
# array([[37.99991]], dtype=float32)

# %%
model.predict(np.array([[100,-250]]))
# Out:
# array([[37.99991]], dtype=float32)
